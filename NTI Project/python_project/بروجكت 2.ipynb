# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset.head(20)
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                   37                     4.9
# 1   0xb379     BANGRES18DEL02                   34                     4.5
# 2   0x5d6d     BANGRES19DEL01                   23                     4.4
# 3   0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4   0x70a2     CHENRES12DEL01                   32                     4.6
# 5   0x9bb4      HYDRES09DEL03                   22                     4.8
# 6   0x95b4   RANCHIRES15DEL01                   33                     4.7
# 7   0x9eb2      MYSRES15DEL02                   35                     4.6
# 8   0x1102      HYDRES05DEL02                   22                     4.8
# 9   0xcdcd      DEHRES17DEL01                   36                     4.2
# 10  0xd987      KOCRES16DEL01                   21                     4.7
# ...

# %%
dataset.tail(20)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 45573  0x6997      MUMRES20DEL02                   26                     4.5
# 45574  0x90c5      MUMRES20DEL03                   21                     4.8
# 45575  0x91d5      HYDRES03DEL03                   34                     4.9
# 45576  0x2bed   RANCHIRES02DEL02                   34                     4.2
# 45577  0x373f      VADRES12DEL03                   25                     4.7
# 45578  0x5640    COIMBRES03DEL02                   30                     4.9
# 45579  0xdf1d      BHPRES19DEL02                   32                     4.6
# 45580  0xbb2b      MYSRES08DEL02                   34                     4.9
# 45581  0x51f0      SURRES02DEL03                   20                     4.9
# 45582  0x59ae     PUNERES13DEL02                   30                     4.6
# 45583  0x5193      MYSRES13DEL02                   36                     4.8
# ...

# %%
dataset.sample(20)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 34277  0xbb54     PUNERES09DEL01                   33                     4.6
# 29204  0x9614      MUMRES11DEL01                   32                     4.8
# 45022  0xb051     CHENRES19DEL03                   30                     4.8
# 5630    0x934     CHENRES09DEL01                 NaN                     NaN
# 39387  0xbe4c     BANGRES17DEL01                   34                     4.9
# 8896   0x47fc     CHENRES09DEL01                   39                     4.2
# 37437  0x962b     INDORES11DEL02                   31                     4.7
# 28256   0xacc      MYSRES06DEL01                   24                     4.7
# 31422  0xc352      DEHRES08DEL03                   21                     4.5
# 29712  0x2956     CHENRES15DEL01                 NaN                     NaN
# 2054   0x73fc   COIMBRES010DEL02                   35                     4.9
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  str
#  1   Delivery_person_ID           45593 non-null  str
#  2   Delivery_person_Age          45593 non-null  str
#  3   Delivery_person_Ratings      45593 non-null  str
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  str
#  9   Time_Orderd                  45593 non-null  str
#  10  Time_Order_picked            45593 non-null  str
#  11  Weatherconditions            45593 non-null  str
#  12  Road_traffic_density         45593 non-null  str
# ...

# %%
dataset.describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         45593.000000          45593.000000                45593.000000
# mean             17.017729             70.231332                   17.465186
# std               8.185109             22.883647                    7.335122
# min             -30.905562            -88.366217                    0.010000
# 25%              12.933284             73.170000                   12.988453
# 50%              18.546947             75.898497                   18.633934
# 75%              22.728163             78.044095                   22.785049
# max              30.914057             88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition
# count                 45593.000000       45593.000000
# mean                     70.845702           1.023359
# std                      21.118812           0.839065
# min                       0.010000           0.000000
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in dataset.select_dtypes(include=['string']).columns:
    dataset[col] = dataset[col].astype(str).str.replace(' ', '', regex=False)

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset['Delivery_person_Age'].value_counts()
# Out:
# Delivery_person_Age
# 35     2262
# 36     2260
# 37     2227
# 30     2226
# 38     2219
# 24     2210
# 32     2202
# 22     2196
# 29     2191
# 33     2187
# 28     2179
# 25     2174
# 34     2166
# 26     2159
# 21     2153
# 27     2150
# 39     2144
# 20     2136
# 31     2120
# 23     2087
# NaN    1854
# 50       53
# 15       38
# Name: count, dtype: int64

# %%
dataset['Delivery_person_Age'] = dataset['Delivery_person_Age'].replace('NaN', np.nan )

# %%
dataset['Delivery_person_Age'].value_counts()
# Out:
# Delivery_person_Age
# 35    2262
# 36    2260
# 37    2227
# 30    2226
# 38    2219
# 24    2210
# 32    2202
# 22    2196
# 29    2191
# 33    2187
# 28    2179
# 25    2174
# 34    2166
# 26    2159
# 21    2153
# 27    2150
# 39    2144
# 20    2136
# 31    2120
# 23    2087
# 50      53
# 15      38
# Name: count, dtype: int64

# %%
dataset['Delivery_person_Age'] = dataset['Delivery_person_Age'].astype('Int64')

# %%
dataset['Delivery_person_Age'].mean()
# Out:
# np.float64(29.567136880129862)

# %%
dataset['Delivery_person_Age'].isnull().sum()
# Out:
# np.int64(1854)

# %%
dataset['Delivery_person_Age'] = dataset['Delivery_person_Age'].replace(np.nan,29)

# %%
dataset['Delivery_person_Age'].value_counts()
# Out:
# Delivery_person_Age
# 29    4045
# 35    2262
# 36    2260
# 37    2227
# 30    2226
# 38    2219
# 24    2210
# 32    2202
# 22    2196
# 33    2187
# 28    2179
# 25    2174
# 34    2166
# 26    2159
# 21    2153
# 27    2150
# 39    2144
# 20    2136
# 31    2120
# 23    2087
# 50      53
# 15      38
# Name: count, dtype: Int64

# %%
dataset['Delivery_person_Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
dataset['Delivery_person_Ratings'].value_counts()
# Out:
# Delivery_person_Ratings
# 4.8    7148
# 4.7    7142
# 4.9    7041
# 4.6    6940
# 5      3996
# 4.5    3303
# NaN    1908
# 4.1    1430
# 4.2    1418
# 4.3    1409
# 4.4    1361
# 4      1077
# 3.5     249
# 3.8     228
# 3.7     225
# 3.6     207
# 3.9     197
# 6        53
# 1        38
# 3.4      32
# 3.1      29
# 3.2      29
# 3.3      25
# 2.6      22
# 2.7      22
# 2.5      20
# 2.8      19
# 2.9      19
# 3         6
# Name: count, dtype: int64

# %%
dataset['Delivery_person_Ratings'] = dataset['Delivery_person_Ratings'].replace('NaN',np.nan)

# %%
dataset['Delivery_person_Ratings'].isnull().sum()
# Out:
# np.int64(1908)

# %%
dataset['Delivery_person_Ratings'].value_counts()
# Out:
# Delivery_person_Ratings
# 4.8    7148
# 4.7    7142
# 4.9    7041
# 4.6    6940
# 5      3996
# 4.5    3303
# 4.1    1430
# 4.2    1418
# 4.3    1409
# 4.4    1361
# 4      1077
# 3.5     249
# 3.8     228
# 3.7     225
# 3.6     207
# 3.9     197
# 6        53
# 1        38
# 3.4      32
# 3.1      29
# 3.2      29
# 3.3      25
# 2.6      22
# 2.7      22
# 2.5      20
# 2.8      19
# 2.9      19
# 3         6
# Name: count, dtype: int64

# %%
dataset['Delivery_person_Ratings'] = dataset['Delivery_person_Ratings'].astype('float64')

# %%
dataset['Delivery_person_Ratings'].mean()
# Out:
# np.float64(4.633780473846858)

# %%
dataset['Delivery_person_Ratings'] = dataset['Delivery_person_Ratings'].replace(np.nan, 4.6)

# %%
dataset['Delivery_person_Ratings'].value_counts()
# Out:
# Delivery_person_Ratings
# 4.6    8848
# 4.8    7148
# 4.7    7142
# 4.9    7041
# 5.0    3996
# 4.5    3303
# 4.1    1430
# 4.2    1418
# 4.3    1409
# 4.4    1361
# 4.0    1077
# 3.5     249
# 3.8     228
# 3.7     225
# 3.6     207
# 3.9     197
# 6.0      53
# 1.0      38
# 3.4      32
# 3.1      29
# 3.2      29
# 3.3      25
# 2.6      22
# 2.7      22
# 2.5      20
# 2.8      19
# 2.9      19
# 3.0       6
# Name: count, dtype: int64

# %%
dataset['Delivery_person_Ratings'].isnull().sum()
# Out:
# np.int64(0)

# %%
dataset[['Restaurant_latitude', 'Restaurant_longitude']].describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude
# count         45593.000000          45593.000000
# mean             17.017729             70.231332
# std               8.185109             22.883647
# min             -30.905562            -88.366217
# 25%              12.933284             73.170000
# 50%              18.546947             75.898497
# 75%              22.728163             78.044095
# max              30.914057             88.433452

# %%
coords = [
    'Restaurant_latitude', 
    'Restaurant_longitude', 
    'Delivery_location_latitude', 
    'Delivery_location_longitude'
]

negative_rows = dataset[(dataset[coords] < 0).any(axis=1)]

negative_rows.groupby(coords).size().reset_index(name='count')
# Out:
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0             -30.905562            -75.832841                   31.045562
# 1             -30.902872             75.826808                   30.972872
# 2             -30.902872             75.826808                   31.012872
# 3             -30.899584             75.809346                   30.929584
# 4             -30.899584             75.809346                   30.949584
# ..                   ...                   ...                         ...
# 415            -9.966783             76.242981                   10.016783
# 416            -9.960846            -76.293936                   10.030846
# 417            -9.960846             76.293936                   10.050846
# 418            -9.959778             76.296106                    9.969778
# 419            -9.959778             76.296106                   10.069778
#
#      Delivery_location_longitude  count
# ...

# %%
dataset['Time_taken(min)'].max()
# Out:
# '(min)54'

# %%
dataset['Restaurant_latitude'] = dataset['Restaurant_latitude'].abs()
dataset['Restaurant_longitude'] = dataset['Restaurant_longitude'].abs()

# %%
(dataset['Restaurant_latitude'] < 1).sum()
# Out:
# np.int64(3640)

# %%
(dataset['Restaurant_longitude'] < 1).sum()
# Out:
# np.int64(3640)

# %%
dataset.loc[dataset['Restaurant_latitude'] < 1,
            ['Restaurant_latitude', 'Restaurant_longitude']] = None

# %%
dataset[['Restaurant_latitude', 'Restaurant_longitude']].isnull().sum()
# Out:
# Restaurant_latitude     3640
# Restaurant_longitude    3640
# dtype: int64

# %%
dataset[['Delivery_location_latitude', 'Delivery_location_longitude']].describe()
# Out:
#        Delivery_location_latitude  Delivery_location_longitude
# count                45593.000000                 45593.000000
# mean                    17.465186                    70.845702
# std                      7.335122                    21.118812
# min                      0.010000                     0.010000
# 25%                     12.988453                    73.280000
# 50%                     18.633934                    76.002574
# 75%                     22.785049                    78.107044
# max                     31.054057                    88.563452

# %%
dataset['Order_Date'] = pd.to_datetime(dataset['Order_Date'], dayfirst=True, format='mixed')

# %%
dataset['Order_Date'].dtype
# Out:
# dtype('<M8[us]')

# %%
dataset[['Time_Orderd', 'Time_Order_picked']].head()
# Out:
#   Time_Orderd Time_Order_picked
# 0    11:30:00          11:45:00
# 1    19:45:00          19:50:00
# 2     8:30:00           8:45:00
# 3    18:00:00          18:10:00
# 4    13:30:00          13:45:00

# %%
dataset['Weatherconditions'].unique()
# Out:
# <StringArray>
# [     'conditionsSunny',     'conditionsStormy', 'conditionsSandstorms',
#      'conditionsCloudy',        'conditionsFog',      'conditionsWindy',
#         'conditionsNaN']
# Length: 7, dtype: str

# %%
dataset['Weatherconditions'] = dataset['Weatherconditions'].str.replace('conditionsNaN', 'unknown')

# %%
dataset['Weatherconditions'].unique()
# Out:
# <StringArray>
# [     'conditionsSunny',     'conditionsStormy', 'conditionsSandstorms',
#      'conditionsCloudy',        'conditionsFog',      'conditionsWindy',
#               'unknown']
# Length: 7, dtype: str

# %%
dataset['Road_traffic_density'].unique()
# Out:
# <StringArray>
# ['High', 'Jam', 'Low', 'Medium', 'NaN']
# Length: 5, dtype: str

# %%
dataset['Road_traffic_density'] = dataset['Road_traffic_density'].str.replace('NaN', 'unknown')

# %%
dataset['Road_traffic_density'].unique()
# Out:
# <StringArray>
# ['High', 'Jam', 'Low', 'Medium', 'unknown']
# Length: 5, dtype: str

# %%
dataset['Vehicle_condition'].unique()
# Out:
# array([2, 0, 1, 3])

# %%
dataset['Type_of_order'].unique()
# Out:
# <StringArray>
# ['Snack', 'Drinks', 'Buffet', 'Meal']
# Length: 4, dtype: str

# %%
dataset['Type_of_vehicle'].unique()
# Out:
# <StringArray>
# ['motorcycle', 'scooter', 'electric_scooter', 'bicycle']
# Length: 4, dtype: str

# %%
dataset['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1      28159
# 0      14095
# 2       1985
# NaN      993
# 3        361
# Name: count, dtype: int64

# %%
dataset['multiple_deliveries'] = dataset['multiple_deliveries'].str.replace('NaN', '1')
dataset['multiple_deliveries'] = dataset['multiple_deliveries'].astype('int64')

# %%
dataset['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1    29152
# 0    14095
# 2     1985
# 3      361
# Name: count, dtype: int64

# %%
dataset['Festival'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'NaN']
# Length: 3, dtype: str

# %%
dataset['Festival'] = dataset['Festival'].str.replace('NaN', 'unknown')

# %%
dataset['Festival'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'unknown']
# Length: 3, dtype: str

# %%
dataset['City'].value_counts()
# Out:
# City
# Metropolitian    34093
# Urban            10136
# NaN               1200
# Semi-Urban         164
# Name: count, dtype: int64

# %%
dataset['City'] = dataset['City'].str.replace('NaN', 'unknown')

# %%
dataset['City'].value_counts()
# Out:
# City
# Metropolitian    34093
# Urban            10136
# unknown           1200
# Semi-Urban         164
# Name: count, dtype: int64

# %%
dataset['Time_taken(min)'].head()
# Out:
# 0    (min)24
# 1    (min)33
# 2    (min)26
# 3    (min)21
# 4    (min)30
# Name: Time_taken(min), dtype: str

# %%
dataset['Time_taken(min)'] = dataset['Time_taken(min)'].str.replace('(min)', ' ').str.strip()
dataset['Time_taken(min)'] = dataset['Time_taken(min)'].astype('int64')

# %%
dataset['Time_taken(min)'].head()
# Out:
# 0    24
# 1    33
# 2    26
# 3    21
# 4    30
# Name: Time_taken(min), dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  str
#  1   Delivery_person_ID           45593 non-null  str
#  2   Delivery_person_Age          45593 non-null  Int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          41953 non-null  float64
#  5   Restaurant_longitude         41953 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  datetime64[us]
#  9   Time_Orderd                  45593 non-null  str
#  10  Time_Order_picked            45593 non-null  str
#  11  Weatherconditions            45593 non-null  str
#  12  Road_traffic_density         45593 non-null  str
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude            3640
# Restaurant_longitude           3640
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# dtype: int64

# %%
dataset.to_csv('train_cleaned.csv', index=False)
